# %%
import pandas as pd
import numpy as np

sys.path.append('./space')
sys.path.append('Python_functions')
sys.path.append('./')
import shear_maps as smap
import smap_plot as smapplt
# Out:
# Can't get data from proxy server http://sciqlop.lpp.polytechnique.fr/cache
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# INFO: Query finished. [astroquery.utils.tap.core]
# This unreleased version of SpacePy is not supported by the SpacePy team.

# %%
smapplt.make_map(90,72, 0, smapplt.JComputer())
# Out:
# Init J
# I made a regular grid
# I imported grids
# I rotated and interpolated
# Jai créé les valeurs de densité

# %%
from importlib import reload
import smap_plot
reload(smap_plot)
# Out:
# <module 'smap_plot' from '/home/imard/Notebooks/Python_functions/smap_plot.py'>
